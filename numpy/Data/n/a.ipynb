# %%
print("shrawan")
# Out:
# shrawan

# %%
# %pip install --upgrade pip
# Out:
# ...
#   Using cached pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.2.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip --version
# Out:
# pip 26.2.1 from c:\Users\shraw\Documents\Python\numpy\Data\myenve\Lib\site-packages\pip (python 3.14)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\shraw\Documents\Python\numpy\Data\myenve\Scripts\python.exe

# %%
# %pip install numpy
# Out:
# ...
#   Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.5.3

# %%
print("nothing")
# Out:
# nothing
