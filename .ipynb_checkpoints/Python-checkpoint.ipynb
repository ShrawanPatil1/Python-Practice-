# %%
print("Hello Python!")
# Out:
# Hello Python!

# %%
a =

# %%
x = {"Hello"}
y = {"New Stack"}
print(x|y)
# Out:
# {'Hello', 'New Stack'}

# %%
def multiply(a, b):
    result = a * b 

product = multiply(2, 3)
print(product)

# Expected result:
# None
# Out:
# None

# %%
x = 2
y = 15

print(x**y)
# Out:
# 32768

# %%
x = 16
y = 5

print(x//y)
# Out:
# 3

# %%
a = 123
a_1 = a % 10
a_2 = (a // 10) % 10
a_3 = a // 100
print(a_1 * 100 + a_2 * 10 + a_3)
# Out:
# 321

# %%
numbers = [1, 2, 3, 4, 5]

if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements
